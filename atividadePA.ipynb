# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelarosaaa/prova-1/blob/main/atividadePA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# questão 1

numero = int(input("digite um numero"))
if numero %2  == 0:
  print (f"este número é par")

else:
  print (f"este número é impar")
# Out:
# digite um numero10
# este número é par

# %%
# questão 2

numero1 = float (input("digite um numero"))
numero2 = float (input("digite um numero"))
if numero1 > numero2:
  print (f"{numero1} é maior que {numero2}")

elif numero1 == numero2:
  print (f"{numero1}  é igual ao {numero2}")

else:
    print(f"{numero2} é maior que {numero1}")
# Out:
# digite um numero6
# digite um numero10
# 10.0 é maior que 6.0

# %%
# questão 3

nota = float(input("digite a nota"))

if nota >= 7:
 print(f" aprovado")

elif 5 <= nota < 7:
  print(f"recuperação")

else:

    print(f"reprovado")
# Out:
# digite a nota6
# recuperação

# %%
# questão 4

idade = int(input('digite a sua idade'))

if idade < 12:
  print(f"criança")

elif  13 <= idade <= 17:
  print(f"adolescente")

elif 18 <= idade <= 59 :
  print(f'adulto')

else:
  print(f"idoso")
# Out:
# digite a sua idade61
# idoso

# %%
# questão 5

senha_fixa = 910

senha_digitada = int(input("digite a senha"))

if senha_digitada == senha_fixa:
  print(f"senha correta")

else:
    print(f"senha incorreta")
# Out:
# digite a senha777
# senha incorreta

# %%
# questão 6

num = int(input("digite um número"))
if num >0:
  print(f"numero positivo")

elif num< 0:
  print(f"numero negativo")

else:
  print(f"numero é 0")
# Out:
# digite um número-10
# numero negativo

# %%
# questão 7

a = int(input("digite um numero"))
b = int(input("digite um numero"))
opcao = int(input("digite uma opção"))

print("opção 1 = soma")
print("opção 2 = subtração")
print("opção 3 = divisao")
print("opção 4 = multiplicação")

if opcao ==1:
 print (f"{a+b}")

elif opcao ==2:
  print(f"{a-b}")

elif opcao == 3:
  print (f"{a/b}")

elif opcao == 4:
  print (f"{a * b}")

else:
  print("digite uma opção valida")
# Out:
# digite um numero5
# digite um numero5
# digite uma opção2
# opção 1 = soma
# opção 2 = subtração
# opção 3 = divisao
# opção 4 = multiplicação
# 0

# %%
# questão 8

dia = int(input("digite um numero"))

if dia == 1:
  print(f"sabado")

elif dia == 2:
  print(f"segunda")

elif dia ==3:
  print(f"terça")

elif dia == 4 :
  print(f"quarta")

elif dia == 5:
  print("quinta")

elif dia == 6:
  print(f"sexta")

elif dia ==7:
  print("domingo")

else :
  print(f"digite um numero de 1 a 7")
# Out:
# digite um numero5
# quinta

# %%
# questão 9

ano = int(input("digite um ano"))

if (ano % 4 == 0 and ano % 100 !=0) or (ano % 400 ==0):
  print(f" o ano {ano} e bissexto")

else :

  print

# %%
# questão 10

val = int(input("digite um valor"))

print = int(input("digite um numero"))


if val >= 100:
